# %% [markdown]
# # prereq

# %%
import torch
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as transforms
import numpy as np
import glob
from natsort import natsorted
import matplotlib.pyplot as plt
import seaborn as sns
from torch.utils.data import Dataset, DataLoader, random_split, Subset

from torch.optim.lr_scheduler import ReduceLROnPlateau,CosineAnnealingLR, StepLR
from sklearn.metrics import f1_score
# Out:
# /Users/anaconda3/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: dlopen(/Users/anaconda3/lib/python3.9/site-packages/torchvision/image.so, 0x0006): Symbol not found: __ZN3c1017RegisterOperatorsD1Ev
#   Referenced from: /Users/anaconda3/lib/python3.9/site-packages/torchvision/image.so
#   Expected in: /Users/anaconda3/lib/python3.9/site-packages/torch/lib/libtorch_cpu.dylib
#   warn(f"Failed to load image Python extension: {e}")

# %%
def plot_images_in_rows(images_list, row_labels=None):
    rows = len(images_list)
    columns = max(len(images) for images in images_list)  # Determine the number of columns needed
    
    fig, axes = plt.subplots(rows, columns, figsize=(20, 5), gridspec_kw={'hspace': 0.5})
    
    for row, (images, label) in enumerate(zip(images_list, row_labels)):
        for col in range(columns):
            if col < len(images):
                axes[row, col].imshow(images[col])
                axes[row, col].axis('off')
            else:
                axes[row, col].axis('off')  # Hide any extra subplots
        if label is not None:
            axes[row, 0].text(-0.25, 0.5, label, transform=axes[row, 0].transAxes, fontsize=12, va='center',rotation=90)

    plt.tight_layout()
    plt.show()

# %%
fol=glob.glob('/Users/shubhamrohal/Documents/GitHub/origami-sensor/figure_7x11/r_top*')
# fol='/Users/shubhamrohal/Documents/GitHub/origami-sensor/figure_2/x_sub'
# print(fol)

x_path=fol[0]+'/(7, 11)/x.npy'
y_path=fol[0]+'/(7, 11)/y.npy'

x=np.squeeze(np.load(x_path),1)
y=np.squeeze(np.load(y_path),1)

print(x[1],y[1])
print(np.shape(x),np.shape(y))
for i in range(20):

    plt.subplot(1,2,1)
    plt.pcolormesh(np.where(x[i]>0, 1, 0))
    plt.subplot(1,2,2)
    plt.pcolormesh(y[i])
    plt.show()
# Out:
# [[15.903049   4.6230216  0.         0.        21.249304   0.
#    0.         0.        22.486614  16.38847    0.       ]
#  [ 0.         9.829134   0.         0.         0.        21.14381
#   17.778553   0.         0.        22.397297   0.       ]
#  [ 0.         0.         0.         0.        15.992384   0.
#    5.3974733  0.         0.         7.8934927  8.2121525]
#  [ 0.        12.056944   0.         8.043087   0.         0.
#    0.         0.         0.         6.7087026  0.       ]
#  [ 0.         0.         0.         0.         0.         0.
#   16.100107   0.         0.         0.         0.       ]
#  [11.108858  10.694482   0.         4.1600666  0.         0.
#    0.         0.         0.        21.471651  22.25568  ]
#  [ 7.3979654 10.336158   8.835605   0.         0.         0.
#   18.848206   0.         0.         0.         0.       ]] [[3.06601369 3.09407649 2.76457954 2.96529382 2.63213933 2.18071708
#   2.92840537 0.         2.28400441 2.93794038 2.79662401]
#  [2.97105989 3.03258775 2.71121168 2.90807866 2.53139175 2.37776416
#   2.93044363 0.         2.10164155 2.8975492  2.76584913]
#  [3.04558802 3.08284534 2.77692185 2.99044992 2.69972043 2.17787283
#   3.07541811 0.         2.10602203 2.99870809 2.97839135]
#  [3.0672444  3.14481597 2.77897682 3.12931854 2.5346373  2.1488106
#   2.93022482 0.         2.09418865 3.07723269 2.8364115 ]
#  [2.49840387 2.50965539 2.34539201 2.41052516 2.16180399 1.86189333
#   2.75646315 0.         1.79531026 2.39247518 2.34937627]
#  [3.21952507 3.24585467 2.87263335 3.28467198 2.54058634 2.14412659
#   2.98004658 0.         2.09817708 3.06253863 2.94102152]
#  [3.32446988 3.27026886 3.19246521 2.98017544 2.4765876  2.10159576
#   3.0768321  0.         2.05740655 2.87809932 2.76890243]]
# (1000, 7, 11) (1000, 7, 11)

# %% [markdown]
# # Dataloader

# %%
class Load_Data(Dataset):
    def __init__(self, data_files, label_files, transform=None):
        self.data_matrices = np.load(data_files+'/y.npy')
        self.label_matrices = np.load(label_files+'/x.npy')
        self.transform = transform

        for i in range(len(self.label_matrices)):
            self.label_matrices[i][self.label_matrices[i] == 0] = 100
        # Ensure the number of data and label matrices match
        assert len(self.data_matrices) == len(self.label_matrices), "Number of data and label files must match"
        
    def __len__(self):
        return len(self.data_matrices)
    
    def __getitem__(self, idx):
        data = self.data_matrices[idx]
        label = self.label_matrices[idx]

        # print(np.where(label==100,0,1),'\n',label)

        sample = {'features': torch.unsqueeze(torch.tensor(data, dtype=torch.float32),0) / 5.0,
                  'target': torch.tensor(label, dtype=torch.float32) / 100.0,
                 'label': torch.tensor(np.where(label == 100, 0, 1), dtype=torch.float32)
                 }
        
        
        if self.transform:
            sample = self.transform(sample)
        
        return sample

# %% [markdown]
# # Model Declaration

# %%
class IsInSeries(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv=nn.Sequential(
            nn.Conv2d(2,4,kernel_size=3),
            nn.Conv2d(4,8,kernel_size=3),
            nn.Conv2d(8,16,kernel_size=3),
        )
        self.linear = nn.Linear(16, 1)
    def forward(self, x):
        x = self.conv(x)
        x = F.avg_pool2d(x, kernel_size=x.shape[-2:])
        x = torch.squeeze(x)
        # print(x.shape)
        x = self.linear(x)
        return x
        
class Net(nn.Module):
    def __init__(self,num_iteration):
        super().__init__()
        self.num_iteration = num_iteration
        self.dropout_prob = 0.8
        self.Conv1=nn.Conv2d(2,77,(1,11))
        self.Conv2= nn.Conv2d(2,77,(7,1))
        self.Conv_list1 = nn.ModuleList([nn.Conv2d(2, 77, (1, 11)) for _ in range(num_iteration)])
        self.Conv_list2 = nn.ModuleList([nn.Conv2d(2, 77, (7, 1)) for _ in range(num_iteration)]) 
        
        self.Tconv1 = nn.ConvTranspose2d(77,2,(1,11))
        self.Tconv2 = nn.ConvTranspose2d(77,2,(7,1))
        
            
        self.Tconv_list1 = nn.ModuleList([nn.ConvTranspose2d(77,2,(1,11)) for _ in range(num_iteration)])
        self.Tconv_list2 = nn.ModuleList([nn.ConvTranspose2d(77,2,(7,1)) for _ in range(num_iteration)])
    
        self.isInSeries = IsInSeries()
        
        self.hard_tanh = nn.Hardtanh(0, 1)
        self.dropout1 = nn.Dropout(p=self.dropout_prob)
        self.dropout2 = nn.Dropout(p=0.3)
    def forward(self, x):
        x=x.repeat(1, 2, 1, 1)
        z=x
        for i in range(self.num_iteration):
            conv_layer1 = self.Conv_list1[i]
            conv_layer2 = self.Conv_list2[i]
            tconv_layer1 = self.Tconv_list1[i]
            tconv_layer2 = self.Tconv_list2[i]
            
            a=F.leaky_relu(self.Conv1(x))
            a=self.Tconv1(a)
            b=F.leaky_relu(self.Conv2(x))
            b=self.Tconv2(b)
            x_middle=torch.sum(torch.stack((a,b),dim=1),1)
            # x = self.dropout1(x)
            
            a = F.relu(conv_layer1(x_middle))
            a = tconv_layer1(a)
            b = F.relu(conv_layer2(x_middle))  
            b = tconv_layer2(b)
            x = torch.sum(torch.stack((a,b),dim=1),1)
            # x = self.dropout2(x)
            # x = F.leaky_relu(x)
            x1 = torch.add(z,x)
            # x2 = 1 / torch.add(z,x)
            # x1 = F.relu(x1)
            # x2 = self.hard_tanh(x2)
            # x2 = F.sigmoid(x2)

            # alpha = self.isInSeries(x1)
            # alpha = torch.unsqueeze(torch.unsqueeze(alpha, -1), -1)
            # print(x1.shape, alpha.shape)
            # x = x1 * alpha + x2 * (1 - alpha)
            x = F.relu(x1)  
            # z=x
        return x

# %% [markdown]
# # Training

# %%
from pathlib import Path
def Training(data_path,label_path,batch,scdulr='',lr=1e-3,depth=10,epoch=100):

    dataset = Load_Data(data_path, label_path)
    num_epochs = epoch

    a=np.shape(dataset)

    
    torch.manual_seed(27)#previous12,27
    
    train_ratio = 0.6
    val_ratio = 0.1
    test_ratio = 0.1

    unseen_ratio = 0.2
    train_ratio =0.8


    batch_size=batch
    
    val_error=[]
    tst_error=[]
    f1_list=[]
    res_error=[]

    
    training_size=int(train_ratio*a[0])

    training_dataset = Subset(dataset, range(training_size))
    
    unseen_dataset = torch.utils.data.Subset(dataset, range(training_size, a[0]))

    separate_dataloader = DataLoader(unseen_dataset, batch_size=batch_size, shuffle=False)

    
    
    if torch.cuda.is_available():
        device = torch.device("cuda")
        print("CUDA is available. Using GPU.")
    else:
        device = torch.device("cpu")
        print("CUDA is not available. Using CPU.")

    
    
    
    net = Net(num_iteration = depth)
    net = net.double()
    
    net = net.to(device)
    
    criterion = nn.MSELoss()
    label_criterion=nn.BCEWithLogitsLoss()
    optimizer = optim.AdamW(net.parameters(), lr=lr, betas=(0.9, 0.999), weight_decay=0.01)
    # optimizer = optim.Adam(net.parameters(), lr=lr)
    if scdulr=='Platue':
        scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=2, verbose=True)
    if scdulr=='Cosine':
        scheduler = CosineAnnealingLR(optimizer, num_epochs, eta_min=lr * 1e-2)

    train_size = int(train_ratio * len(training_dataset))
    val_size = int(val_ratio * len(training_dataset))
    test_size = len(training_dataset) - train_size - val_size

    train_dataset, val_dataset, test_dataset = random_split(training_dataset, [train_size, val_size, test_size])

    train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

    alpha,beta=0.7,0.3

    epsilon=1e-8
    for epoch in range(num_epochs):
        net.train()
        epoch_loss = 0.0

        # if epoch>0:
        #     alpha = 1/(output_loss.item() +epsilon)
        #     beta = 1/(label_loss.item() + epsilon)
        #     weight_sum = alpha + beta
        #     alpha /= weight_sum
        #     beta /= weight_sum
        for batch in train_dataloader:
            features, targets, labels = batch['features'], batch['target'], batch['label']

            # Zero the parameter gradients
            optimizer.zero_grad()

            features = features.squeeze(1)
            targets = targets.squeeze(1)
            labels = labels.squeeze(1)

            
            features = features.to(device)
            targets = targets.to(device)
            labels = labels.to(device)
        
            # Forward pass
            outputs = net(features.double())
#             print('output device:',outputs.get_device())
            outputs, predicted_labels = torch.transpose(outputs, 0, 1)
            output_loss = criterion(outputs, targets.double())
            label_loss = label_criterion(predicted_labels, labels.double())
            loss = (alpha * output_loss + beta * label_loss)/2
            # Backward pass and optimize
            loss.backward()
            optimizer.step()

            # Accumulate the loss
            epoch_loss += loss.item()

        # Calculate and print the average loss for the epoch
        average_loss = epoch_loss / len(train_dataloader)
        print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {average_loss:.4f}')

        # Validation phase
        net.eval()
        val_loss = 0.0
        out_loss = 0.0
        total_f1 = 0.0
        with torch.no_grad():
            for batch in val_dataloader:
                features, targets, labels = batch['features'], batch['target'], batch['label']

                features=features.squeeze(1)
                targets=targets.squeeze(1)
                labels=labels.squeeze(1)
                
                features = features.to(device)
                targets = targets.to(device)
                labels = labels.to(device)
                
                outputs = net(features.double())
                outputs, predicted_labels = torch.transpose(outputs, 0, 1)
                output_loss = criterion(outputs, targets.double())
                label_loss = label_criterion(predicted_labels,labels.double())
                loss=(alpha * output_loss + beta * label_loss)/2
                out_loss += output_loss.item()
                val_loss += loss.item()

                # Calculate F1 score
                outputs_sigmoid = torch.sigmoid(predicted_labels)
                outputs_np = outputs_sigmoid.cpu().numpy().flatten()
                targets_np = labels.cpu().numpy().flatten()
                outputs_bin = (outputs_np > 0.5).astype(int)  # Binarize the outputs
                # print(outputs_bin, targets_np)
                # targets_bin = targets_np.astype(int)
                f1 = f1_score(targets_np, outputs_bin, average='macro')
                total_f1 += f1

        val_loss /= len(val_dataloader)
        out_loss /= len(val_dataloader)
        average_f1 = total_f1 / len(val_dataloader)
        print(f'Validation Loss: {output_loss:.4f}, Validation F1 Score: {average_f1:.4f}, Label loss:{label_loss:.4f}, {alpha:.3f},{beta:.3f}')

        save = Path(f'{data_path[:-1]}/dong/')
        
        if not save.exists():
            save.mkdir(parents=True)
            
        torch.save(net.state_dict(),f'{data_path[:-1]}/dong/model_{depth}.pth')

        if scdulr=='Platue':
            scheduler.step(val_loss)
            # scheduler.step()
        if scdulr=='Cosine':
            scheduler.step()
        

    # Final evaluation on test data
    net.eval()
    test_loss = 0.0
    total_f1 = 0.0
    with torch.no_grad():
        for batch in test_dataloader:
            features, targets, labels = batch['features'], batch['target'], batch['label']

            features=features.squeeze(1)
            targets=targets.squeeze(1)
            labels=labels.squeeze(1)
            
            features = features.to(device)
            targets = targets.to(device)
            labels = labels.to(device)
            
            outputs = net(features.double())
            
            outputs, predicted_labels = torch.transpose(outputs, 0, 1)
            output_loss = criterion(outputs, targets.double())
            label_loss = label_criterion(predicted_labels,labels.double())
            loss=(output_loss + label_loss *0.5)/2
            # loss=(output_loss + label_loss)/2
            test_loss += loss.item()

            # Calculate F1 score
            outputs_sigmoid = torch.sigmoid(predicted_labels)
            outputs_np = outputs_sigmoid.cpu().numpy().flatten()
            targets_np = labels.cpu().numpy().flatten()
            outputs_bin = (outputs_np > 0.5).astype(int)  # Binarize the outputs
            # print(outputs_bin, targets_np)
            # targets_bin = targets_np.astype(int)
            f1 = f1_score(targets_np, outputs_bin, average='macro')
            total_f1 += f1

    test_loss /= len(test_dataloader)
    average_f1 = total_f1 / len(test_dataloader)
    
    val_error.append(val_loss)
    tst_error.append(test_loss)
    
    print(f'Final Test Loss: {test_loss:.4f}, Final Test F1 Score: {average_f1:.4f}, Label loss:{label_loss}')

    print("Training complete")

    return average_f1

# %%
fol=glob.glob('/Users/shubhamrohal/Documents/GitHub/origami-sensor/figure_7x11/r_top=*')
fol=natsorted(fol)
# fol=fol[6:]
# rev=list(reversed(fol))
# print(fol,'\n',fol[6:])
all_r_top,all_r_bottom,all_f1 = [],[],[]
for i in fol:
    print(i)
    
    isplit=i.split('/')
    isplit=isplit[-1].split(',')
    
    a=isplit[0].split('=')
    b=isplit[1].split('=')
    a=a[-1]
    b=b[-1]
    data_path=i+'/(7, 11)/'
    F1 = Training(data_path,data_path,scdulr='Cosine',lr=1e-3,depth=3)# scheduler Platue, Cosine
    
    all_r_top.append(a)
    all_r_bottom.append(b)
    all_f1.append(F1)
# Out:
# /Users/shubhamrohal/Documents/GitHub/origami-sensor/figure_7x11/r_top=0.02,r_bottom=0.02
# CUDA is not available. Using CPU.
# Epoch [1/100], Loss: 0.2390
# Validation Loss: 0.1984, Validation F1 Score: 0.6219, Label loss:0.6915, 0.500,0.500
# Epoch [2/100], Loss: 0.1457
# Validation Loss: 0.1602, Validation F1 Score: 0.6079, Label loss:0.6917, 0.777,0.223
# Epoch [3/100], Loss: 0.1280
# Validation Loss: 0.1438, Validation F1 Score: 0.6287, Label loss:0.6913, 0.812,0.188
# Epoch [4/100], Loss: 0.1160
# Validation Loss: 0.1267, Validation F1 Score: 0.7023, Label loss:0.6893, 0.828,0.172
# Epoch [5/100], Loss: 0.1039
# Validation Loss: 0.1132, Validation F1 Score: 0.7195, Label loss:0.6856, 0.845,0.155
# Epoch [6/100], Loss: 0.0941
# Validation Loss: 0.1046, Validation F1 Score: 0.7262, Label loss:0.6813, 0.858,0.142
# Epoch [7/100], Loss: 0.0863
# Validation Loss: 0.0964, Validation F1 Score: 0.7570, Label loss:0.6758, 0.867,0.133
# Epoch [8/100], Loss: 0.0780
# Validation Loss: 0.0800, Validation F1 Score: 0.7485, Label loss:0.6695, 0.875,0.125
# Epoch [9/100], Loss: 0.0674
# Validation Loss: 0.0730, Validation F1 Score: 0.7508, Label loss:0.6654, 0.893,0.107
# Epoch [10/100], Loss: 0.0617
# Validation Loss: 0.0625, Validation F1 Score: 0.7736, Label loss:0.6614, 0.901,0.099
# Epoch [11/100], Loss: 0.0551
# Validation Loss: 0.0584, Validation F1 Score: 0.7777, Label loss:0.6583, 0.914,0.086
# Epoch [12/100], Loss: 0.0514
# Validation Loss: 0.0565, Validation F1 Score: 0.7764, Label loss:0.6560, 0.919,0.081
# Epoch [13/100], Loss: 0.0479
# Validation Loss: 0.0506, Validation F1 Score: 0.7647, Label loss:0.6513, 0.921,0.079
# Epoch [14/100], Loss: 0.0441
# Validation Loss: 0.0465, Validation F1 Score: 0.7809, Label loss:0.6472, 0.928,0.072
# Epoch [15/100], Loss: 0.0413
# Validation Loss: 0.0447, Validation F1 Score: 0.7857, Label loss:0.6439, 0.933,0.067
# Epoch [16/100], Loss: 0.0392
# Validation Loss: 0.0444, Validation F1 Score: 0.7763, Label loss:0.6392, 0.935,0.065
# Epoch [17/100], Loss: 0.0382
# Validation Loss: 0.0447, Validation F1 Score: 0.7864, Label loss:0.6362, 0.935,0.065
# Epoch [91/100], Loss: 0.0370
# Validation Loss: 0.0523, Validation F1 Score: 0.8853, Label loss:0.5796, 0.918,0.082
# Epoch [92/100], Loss: 0.0372
# Validation Loss: 0.0508, Validation F1 Score: 0.8820, Label loss:0.5776, 0.917,0.083
# Epoch [93/100], Loss: 0.0366
# Validation Loss: 0.0495, Validation F1 Score: 0.8841, Label loss:0.5760, 0.919,0.081
# Epoch [94/100], Loss: 0.0362
# Validation Loss: 0.0529, Validation F1 Score: 0.8883, Label loss:0.5861, 0.921,0.079
# Epoch [95/100], Loss: 0.0371
# Validation Loss: 0.0516, Validation F1 Score: 0.8847, Label loss:0.5805, 0.917,0.083
# Epoch [96/100], Loss: 0.0367
# Validation Loss: 0.0511, Validation F1 Score: 0.8855, Label loss:0.5795, 0.918,0.082
# Epoch [97/100], Loss: 0.0365
# Validation Loss: 0.0508, Validation F1 Score: 0.8860, Label loss:0.5781, 0.919,0.081
# Epoch [98/100], Loss: 0.0363
# Validation Loss: 0.0496, Validation F1 Score: 0.8824, Label loss:0.5764, 0.919,0.081
# Epoch [99/100], Loss: 0.0360
# Validation Loss: 0.0503, Validation F1 Score: 0.8857, Label loss:0.5774, 0.921,0.079
# Epoch [100/100], Loss: 0.0360
# Validation Loss: 0.0533, Validation F1 Score: 0.8864, Label loss:0.5817, 0.920,0.080
# Final Test Loss: 0.1645, Final Test F1 Score: 0.8995, Label loss:0.5914561243760414
# Training complete

# %% [markdown]
# # Plot

# %%
# print(all_f1,'\n',all_r_top,'\n',all_r_bottom)

j=0
all_f1_2d=[]
all_r1,all_r2=[],[]

save_path=data_path.split('r_')
print(save_path[0])
df=pd.DataFrame({'R_top':all_r_top, 'R_bottom': all_r_bottom, 'F1_score': all_f1})

tdf= df#.iloc[::-1]
tdf_f1=tdf['F1_score']
# tdf.to_csv(f'{save_path[0]}f1_score_model_4.csv')
for i in range(6,len(all_f1)+1,6):
    temp=[]
    temp=tdf_f1[j:i]
    all_f1_2d.append(temp)
    j=i
x=[0, 1, 2, 3, 4, 5]
# print(tdf_f1)

# plt.pcolormesh(x,x,all_f1_2d, vmin=0.9, vmax=.95,edgecolors='w')
all_f1_2d=np.array(all_f1_2d)

fig, ax = plt.subplots()
c = ax.pcolormesh(x,x,all_f1_2d, vmin=0.85, vmax=.95, cmap='viridis')

# Add color bar
fig.colorbar(c, ax=ax)

# Annotate each cell with the numeric value
for i in range(all_f1_2d.shape[0]):
    for j in range(all_f1_2d.shape[0]):
        ax.text(j + 0.0, i + 0.0, f'{all_f1_2d[i, j]:.3f}',
                ha='center', va='center', color='white')
plt.ylabel('R_top')
plt.xlabel('R_bottom')
plt.show()
# Out:
# /Users/shubhamrohal/Documents/GitHub/origami-sensor/figure_7x11/

# %%
import pandas as pd

# %%
# print(all_f1,'\n',all_r_top,'\n',all_r_bottom)

j=0
all_f1_2d=[]
all_r1,all_r2=[],[]

save_path=data_path.split('r_')
print(save_path[0])
df=pd.DataFrame({'R_top':all_r_top, 'R_bottom': all_r_bottom, 'F1_score': all_f1})

tdf= df#.iloc[::-1]
tdf_f1=tdf['F1_score']
# tdf.to_csv(f'{save_path[0]}f1_score_model_4.csv')
for i in range(6,len(all_f1)+1,6):
    temp=[]
    temp=tdf_f1[j:i]
    all_f1_2d.append(temp)
    j=i
x=[0, 1, 2, 3, 4, 5]
# print(tdf_f1)

# plt.pcolormesh(x,x,all_f1_2d, vmin=0.9, vmax=.95,edgecolors='w')
all_f1_2d=np.array(all_f1_2d)

fig, ax = plt.subplots()
c = ax.pcolormesh(x,x,all_f1_2d, vmin=0.9, vmax=.95, cmap='viridis')

# Add color bar
fig.colorbar(c, ax=ax)

# Annotate each cell with the numeric value
for i in range(all_f1_2d.shape[0]):
    for j in range(all_f1_2d.shape[0]):
        ax.text(j + 0.0, i + 0.0, f'{all_f1_2d[i, j]:.3f}',
                ha='center', va='center', color='white')
plt.ylabel('R_top')
plt.xlabel('R_bottom')
plt.show()

# %%
fol=glob.glob('r_top=3.0,r_bottom=0.02')
fol=natsorted(fol)
rev=list(reversed(fol))

our_depth,our_f1=[],[]

depth_val=[4,5,6,7,10,12,14,16,18,36]
# for depth in range(4,10):
for depth in range(5,16):
    F1_our=0
    i=rev[0]
    print(i, depth)
    
    isplit=i.split('/')
    isplit=isplit[-1].split(',')
    
    a=isplit[0].split('=')
    b=isplit[1].split('=')
    a=a[-1]
    b=b[-1]
    data_path=i+'/(7, 11)/'
    lr = 5e-3 / (depth * 1.5)
    print(lr)
    F1_our = Training(data_path,data_path,batch=16,scdulr='Cosine',lr=lr,depth=depth,epoch=100)# scheduler Platue, Cosine

    our_depth.append(depth)
    our_f1.append(F1_our)
# Out:
# r_top=3.0,r_bottom=0.02 5
# 0.0006666666666666666
# CUDA is not available. Using CPU.
# Epoch [1/100], Loss: 0.2458
# Validation Loss: 0.2316, Validation F1 Score: 0.6097, Label loss:0.6949, 0.500,0.500
# Epoch [2/100], Loss: 0.1612
# Validation Loss: 0.1879, Validation F1 Score: 0.6297, Label loss:0.6909, 0.750,0.250
# Epoch [3/100], Loss: 0.1423
# Validation Loss: 0.1678, Validation F1 Score: 0.6550, Label loss:0.6888, 0.786,0.214
# Epoch [4/100], Loss: 0.1313
# Validation Loss: 0.1560, Validation F1 Score: 0.6567, Label loss:0.6884, 0.804,0.196
# Epoch [5/100], Loss: 0.1230
# Validation Loss: 0.1438, Validation F1 Score: 0.6710, Label loss:0.6878, 0.815,0.185
# Epoch [6/100], Loss: 0.1152
# Validation Loss: 0.1315, Validation F1 Score: 0.6819, Label loss:0.6867, 0.827,0.173
# Epoch [7/100], Loss: 0.1073
# Validation Loss: 0.1238, Validation F1 Score: 0.6811, Label loss:0.6862, 0.839,0.161
# Epoch [8/100], Loss: 0.1015
# Validation Loss: 0.1150, Validation F1 Score: 0.6814, Label loss:0.6848, 0.847,0.153
# Epoch [9/100], Loss: 0.0953
# Validation Loss: 0.1094, Validation F1 Score: 0.6924, Label loss:0.6833, 0.856,0.144
# Epoch [10/100], Loss: 0.0905
# Validation Loss: 0.1018, Validation F1 Score: 0.7015, Label loss:0.6814, 0.862,0.138
# Epoch [11/100], Loss: 0.0848
# Validation Loss: 0.0981, Validation F1 Score: 0.7155, Label loss:0.6795, 0.870,0.130
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[298], line 24
#      22 lr = 5e-3 / (depth * 1.5)
#      23 print(lr)
# ---> 24 F1_our = Training(data_path,data_path,batch=16,scdulr='Cosine',lr=lr,depth=depth,epoch=100)# scheduler Platue, Cosine
#      26 our_depth.append(depth)
#      27 our_f1.append(F1_our)
#
# Cell In[239], line 85, in Training(data_path, label_path, batch, scdulr, lr, depth, epoch)
#      83     alpha /= weight_sum
#      84     beta /= weight_sum
# ---> 85 for batch in train_dataloader:
#      86     features, targets, labels = batch['features'], batch['target'], batch['label']
#      88     # Zero the parameter gradients
#
# File /Users/anaconda3/lib/python3.9/site-packages/torch/utils/data/dataloader.py:644, in _BaseDataLoaderIter.__next__(self)
#     640         warn_msg += ("For multiprocessing data-loading, this could be caused by not properly configuring the "
#     641                      "IterableDataset replica at each worker. Please see "
#     642                      "https://pytorch.org/docs/stable/data.html#torch.utils.data.IterableDataset for examples.")
#     643     warnings.warn(warn_msg)
# --> 644 return data
#
# KeyboardInterrupt:

# %%
plt.plot(our_depth,our_f1)
plt.scatter(our_depth,our_f1)
plt.grid()

# %%
our_f1[2]
# Out:
# 0.910933581921153

# %% [markdown]
# ## Visualization

# %%
fol=glob.glob('r_top=3.0,r_bottom=0.02')
data_path = fol[0]+'/(7, 11)/'
label_path = data_path
dataset = Load_Data(data_path, label_path)

a=np.shape(dataset)

train_ratio = 0.8
val_ratio = 0.1
test_ratio = 0.1

unseen_ratio = 0.2
train_ratio =0.8


batch_size=8

val_error=[]
tst_error=[]
f1_list=[]
res_error=[]


training_size=int(train_ratio*a[0])

training_dataset = Subset(dataset, range(training_size))

unseen_dataset = torch.utils.data.Subset(dataset, range(training_size, a[0]))

separate_dataloader = DataLoader(unseen_dataset, batch_size=batch_size, shuffle=False)

# %%
all_f1=[]
for batch in separate_dataloader:
    features, targets, labels = batch['features'], batch['target'], batch['label']

    
    features = features.squeeze(1)
    features = features.squeeze(1)
    labels = labels.squeeze(1)
    labels = labels.squeeze(1)
    targets = targets.squeeze(1)
    targets = targets.squeeze(1)
    targets = targets.squeeze(1)

    labels=labels.double().detach().numpy()
    # print(np.shape(labels))
    
    model = Net(num_iteration = 4)
    model = model.double()

    model.load_state_dict(torch.load(data_path+'model_4.pth'))
    # model.load_state_dict(torch.load(data_path+'model_schedulerCosine_10.pth'))

    
    predicted_list,output_list,temp_pred=[],[],[]
    for i in features:
        output = model(i.double())
        output, predicted_label = torch.transpose(output, 0, 1)
        output = output.squeeze(0)
        output = output.double().detach().numpy()
        predicted_label = torch.sigmoid(predicted_label)
        predicted_label = predicted_label.squeeze(0)
        predicted_label = predicted_label.double().detach().numpy()
        predicted_label = (predicted_label > 0.5).astype(int)
        predicted_list.append(predicted_label)
        temp_pred.append(predicted_label)
        output_list.append(output*100)

    # print(temp_pred)
    for i in range(len(labels)):
        f1=0.0
        # print((labels[i]))
        f1 = f1_score(labels[i], temp_pred[i], average='macro')
        all_f1.append(f1)
    label=['Input','Output', 'Ground T']
    plot_images_in_rows([features.double().detach().numpy(),predicted_list,labels],label)
print(np.mean(all_f1))
# Out:
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /var/folders/r1/z0_zcrw973bgh_p1grs6t1qm0000gn/T/ipykernel_3814/2159719848.py:17: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /var/folders/r1/z0_zcrw973bgh_p1grs6t1qm0000gn/T/ipykernel_3814/2159719848.py:17: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /var/folders/r1/z0_zcrw973bgh_p1grs6t1qm0000gn/T/ipykernel_3814/2159719848.py:17: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /var/folders/r1/z0_zcrw973bgh_p1grs6t1qm0000gn/T/ipykernel_3814/2159719848.py:17: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /var/folders/r1/z0_zcrw973bgh_p1grs6t1qm0000gn/T/ipykernel_3814/2159719848.py:17: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /var/folders/r1/z0_zcrw973bgh_p1grs6t1qm0000gn/T/ipykernel_3814/2159719848.py:17: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /var/folders/r1/z0_zcrw973bgh_p1grs6t1qm0000gn/T/ipykernel_3814/2159719848.py:17: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /var/folders/r1/z0_zcrw973bgh_p1grs6t1qm0000gn/T/ipykernel_3814/2159719848.py:17: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /var/folders/r1/z0_zcrw973bgh_p1grs6t1qm0000gn/T/ipykernel_3814/2159719848.py:17: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /var/folders/r1/z0_zcrw973bgh_p1grs6t1qm0000gn/T/ipykernel_3814/2159719848.py:17: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /var/folders/r1/z0_zcrw973bgh_p1grs6t1qm0000gn/T/ipykernel_3814/2159719848.py:17: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /var/folders/r1/z0_zcrw973bgh_p1grs6t1qm0000gn/T/ipykernel_3814/2159719848.py:17: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /var/folders/r1/z0_zcrw973bgh_p1grs6t1qm0000gn/T/ipykernel_3814/2159719848.py:17: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /var/folders/r1/z0_zcrw973bgh_p1grs6t1qm0000gn/T/ipykernel_3814/2159719848.py:17: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /var/folders/r1/z0_zcrw973bgh_p1grs6t1qm0000gn/T/ipykernel_3814/2159719848.py:17: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /var/folders/r1/z0_zcrw973bgh_p1grs6t1qm0000gn/T/ipykernel_3814/2159719848.py:17: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /var/folders/r1/z0_zcrw973bgh_p1grs6t1qm0000gn/T/ipykernel_3814/2159719848.py:17: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /var/folders/r1/z0_zcrw973bgh_p1grs6t1qm0000gn/T/ipykernel_3814/2159719848.py:17: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /var/folders/r1/z0_zcrw973bgh_p1grs6t1qm0000gn/T/ipykernel_3814/2159719848.py:17: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /var/folders/r1/z0_zcrw973bgh_p1grs6t1qm0000gn/T/ipykernel_3814/2159719848.py:17: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /var/folders/r1/z0_zcrw973bgh_p1grs6t1qm0000gn/T/ipykernel_3814/2159719848.py:17: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /var/folders/r1/z0_zcrw973bgh_p1grs6t1qm0000gn/T/ipykernel_3814/2159719848.py:17: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /var/folders/r1/z0_zcrw973bgh_p1grs6t1qm0000gn/T/ipykernel_3814/2159719848.py:17: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /var/folders/r1/z0_zcrw973bgh_p1grs6t1qm0000gn/T/ipykernel_3814/2159719848.py:17: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /var/folders/r1/z0_zcrw973bgh_p1grs6t1qm0000gn/T/ipykernel_3814/2159719848.py:17: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# 0.8192172701036339

# %%
path=glob.glob('real_word_example_7x11/OMSense/*')

patterns=[ i for i in path if i[-3:] !='jpg']

patterns=natsorted(patterns)


model = Net(num_iteration = 5)
model = model.double()

model.load_state_dict(torch.load(data_path+'model_5.pth'))

def adc_to_vol(arr):
    out=np.array(arr)*(5/1024)
    return out

for i in patterns:
    files=glob.glob(i+'/*.csv')
    print(i)
    input_arr = np.loadtxt(files[2000],delimiter=',')
    input_arr=adc_to_vol(input_arr)
    input_arr = np.transpose(input_arr)/5.0
    # input_arr = np.flipud(input_arr)
    feature = torch.unsqueeze(torch.tensor(input_arr, dtype=torch.float32),0) 
    output = model(feature.double())
    
    output, predicted_label = torch.transpose(output, 0, 1)
    output = output.squeeze(0)
    output = output.double().detach().numpy()
    predicted_label = torch.sigmoid(predicted_label)
    predicted_label = predicted_label.squeeze(0)
    predicted_label = predicted_label.double().detach().numpy()
    predicted_label = (predicted_label > 0.5).astype(int)
    
    out=predicted_label*input_arr
    # print(output*100)
    plt.subplot(1,2,1)
    plt.pcolormesh(input_arr)
    plt.subplot(1,2,2)
    plt.pcolormesh(np.where(output > 0.75, 0, output))
    plt.show()
# Out:
# real_word_example_7x11/OMSense/pattern1
# real_word_example_7x11/OMSense/pattern2
# real_word_example_7x11/OMSense/pattern3
# real_word_example_7x11/OMSense/pattern4
# real_word_example_7x11/OMSense/pattern5
# real_word_example_7x11/OMSense/pattern6
# real_word_example_7x11/OMSense/pattern7

# %%
data_path
# Out:
# 'r_top=3.0,r_bottom=0.02/(7, 11)/'

# %%
F1_our = Training(data_path,data_path,scdulr='Cosine',lr=1e-3,depth=4,epoch=100)# scheduler Platue, Cosine
# Out:
# CUDA is not available. Using CPU.
# Epoch [1/100], Loss: 0.2492
# Validation Loss: 0.1880, Validation F1 Score: 0.4426, Label loss:0.6930, 0.500,0.500
# Epoch [2/100], Loss: 0.1403
# Validation Loss: 0.1544, Validation F1 Score: 0.4681, Label loss:0.6926, 0.787,0.213
# Epoch [3/100], Loss: 0.1219
# Validation Loss: 0.1392, Validation F1 Score: 0.5737, Label loss:0.6915, 0.818,0.182
# Epoch [4/100], Loss: 0.1114
# Validation Loss: 0.1214, Validation F1 Score: 0.6513, Label loss:0.6878, 0.832,0.168
# Epoch [5/100], Loss: 0.1001
# Validation Loss: 0.1053, Validation F1 Score: 0.6997, Label loss:0.6817, 0.850,0.150
# Epoch [6/100], Loss: 0.0894
# Validation Loss: 0.0973, Validation F1 Score: 0.7038, Label loss:0.6761, 0.866,0.134
# Epoch [7/100], Loss: 0.0831
# Validation Loss: 0.0838, Validation F1 Score: 0.7431, Label loss:0.6738, 0.874,0.126
# Epoch [8/100], Loss: 0.0753
# Validation Loss: 0.0808, Validation F1 Score: 0.7460, Label loss:0.6701, 0.889,0.111
# Epoch [9/100], Loss: 0.0721
# Validation Loss: 0.0707, Validation F1 Score: 0.7607, Label loss:0.6669, 0.892,0.108
# Epoch [10/100], Loss: 0.0664
